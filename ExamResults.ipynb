# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('FE08Results.XLSX')

# %%
df.head()
# Out:
#    S/S                  Ad Soyad  Task 1  Task 2  Task 3  Task 4  Task 5  \
# 0    1    Aghajamal Aslanov Ziya       6      10       0      10       0
# 1    2    Arif Haciyev Agamemmed      10      10       6      10       6
# 2    3  Cabbar Isgəndərli Ağalar       6       7       6      10      10
# 3    4          Dmitriy Semyonov       6      10      10      10      10
# 4    5     Elmar Nərimanov Zakir       3       0       0       2       0
#
#    Task 6  Task 7  Task 8  Task 9  Task 10
# 0       7      10       4     4.0        2
# 1      10      10      10     4.0        5
# 2       8      10       8     4.0        0
# 3      10      10      10    10.0        0
# 4       0       0       0     0.0        0

# %%
df.drop(['S/S','Ad Soyad'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Task 1', 'Task 2', 'Task 3', 'Task 4', 'Task 5', 'Task 6', 'Task 7',
#        'Task 8', 'Task 9', 'Task 10'],
#       dtype='object')

# %% [markdown]
# # İlkin baxış

# %%
df.describe()
# Out:
#           Task 1     Task 2     Task 3     Task 4     Task 5     Task 6  \
# count  41.000000  41.000000  41.000000  41.000000  41.000000  41.000000
# mean    5.439024   6.170732   4.317073   6.243902   6.756098   5.756098
# std     2.460171   4.061419   3.791036   3.726798   4.351899   3.845650
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     6.000000   0.000000   0.000000   3.000000   1.000000   2.000000
# 50%     6.000000   7.000000   5.000000   7.000000  10.000000   8.000000
# 75%     6.000000  10.000000   8.000000  10.000000  10.000000   8.000000
# max    10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
#
#           Task 7     Task 8     Task 9    Task 10
# count  41.000000  41.000000  41.000000  41.000000
# mean    7.317073   4.390244   4.231707   3.219512
# std     4.297901   4.212351   3.811328   3.927545
# min     0.000000   0.000000   0.000000   0.000000
# 25%     3.000000   0.000000   0.000000   0.000000
# ...

# %% [markdown]
# # Bütün suallar üzrə qiymət paylanması

# %%
df.hist(figsize=(12,8), bins=10)
plt.suptitle('Tapşırıqlar üzrə nəticələr', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# Ümumi nəticə sütunun əlavə olunması

# %%
df['Total'] = df.apply(lambda row: sum(row),axis=1)

# %%
df.head()
# Out:
#    Task 1  Task 2  Task 3  Task 4  Task 5  Task 6  Task 7  Task 8  Task 9  \
# 0       6      10       0      10       0       7      10       4     4.0
# 1      10      10       6      10       6      10      10      10     4.0
# 2       6       7       6      10      10       8      10       8     4.0
# 3       6      10      10      10      10      10      10      10    10.0
# 4       3       0       0       2       0       0       0       0     0.0
#
#    Task 10  Total
# 0        2   53.0
# 1        5   81.0
# 2        0   69.0
# 3        0   86.0
# 4        0    5.0

# %% [markdown]
# # Korelyasiya üzrə heatmap.
# Hansı tapşırıq total nəticəyə necə təsir edir?

# %%
plt.figure(figsize = (9,9))
sns.heatmap(data=df.corr(),annot=True)
plt.show()
